# %%
import numpy as np
from datascience import *

# %% [markdown]
# ## Group

# %%
nba = Table.read_table('nba_salaries.csv')
nba.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PLAYER</th> <th>POSITION</th> <th>TEAM</th> <th>'15-'16 SALARY</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Paul Millsap            </td> <td>PF      </td> <td>Atlanta Hawks         </td> <td>18.6717       </td>
#         </tr>
#         <tr>
#             <td>Al Horford              </td> <td>C       </td> <td>Atlanta Hawks         </td> <td>12            </td>
#         </tr>
#         <tr>
#             <td>Tiago Splitter          </td> <td>C       </td> <td>Atlanta Hawks         </td> <td>9.75625       </td>
#         </tr>
#         <tr>
#             <td>Jeff Teague             </td> <td>PG      </td> <td>Atlanta Hawks         </td> <td>8             </td>
#         </tr>
#         <tr>
#             <td>Kyle Korver             </td> <td>SG      </td> <td>Atlanta Hawks         </td> <td>5.74648       </td>
#         </tr>
#         <tr>
# ...

# %%
movies = Table.read_table('top_movies.csv')
movies
# Out:
# Title                                     | Studio               | Gross     | Gross (Adjusted) | Year
# Star Wars: The Force Awakens              | Buena Vista (Disney) | 906723418 | 906723400        | 2015
# Avatar                                    | Fox                  | 760507625 | 846120800        | 2009
# Titanic                                   | Paramount            | 658672302 | 1178627900       | 1997
# Jurassic World                            | Universal            | 652270625 | 687728000        | 2015
# Marvel's The Avengers                     | Buena Vista (Disney) | 623357910 | 668866600        | 2012
# The Dark Knight                           | Warner Bros.         | 534858444 | 647761600        | 2008
# Star Wars: Episode I - The Phantom Menace | Fox                  | 474544677 | 785715000        | 1999
# Star Wars                                 | Fox                  | 460998007 | 1549640500       | 1977
# ...

# %%
actors = Table.read_table('actors.csv')
actors
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie                     | Gross
# Harrison Ford      | 4871.7      | 41               | 118.8             | Star Wars: The Force Awakens | 936.7
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers                 | 623.4
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight              | 534.9
# Tom Hanks          | 4340.8      | 44               | 98.7              | Toy Story 3                  | 415
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers                 | 623.4
# Eddie Murphy       | 3810.4      | 38               | 100.3             | Shrek 2                      | 441.2
# Tom Cruise         | 3587.2      | 36               | 99.6              | War of the Worlds            | 234.3
# ...

# %%
nba.group("TEAM")
# Out:
# TEAM                  | count
# Atlanta Hawks         | 14
# Boston Celtics        | 15
# Brooklyn Nets         | 13
# Charlotte Hornets     | 18
# Chicago Bulls         | 12
# Cleveland Cavaliers   | 10
# Dallas Mavericks      | 11
# Denver Nuggets        | 14
# Detroit Pistons       | 10
# Golden State Warriors | 14
# ... (20 rows omitted)

# %%
# Write a statement that creates a table that shows the number of movies per studio

# %%
# Write a statement that creates a table that shows the largest movie gross per studio

# %% [markdown]
# ## Pivot

# %%
nba.pivot('TEAM', 'POSITION', "'15-'16 SALARY", np.max)
# Out:
# POSITION | Atlanta Hawks | Boston Celtics | Brooklyn Nets | Charlotte Hornets | Chicago Bulls | Cleveland Cavaliers | Dallas Mavericks | Denver Nuggets | Detroit Pistons | Golden State Warriors | Houston Rockets | Indiana Pacers | Los Angeles Clippers | Los Angeles Lakers | Memphis Grizzlies | Miami Heat | Milwaukee Bucks | Minnesota Timberwolves | New Orleans Pelicans | New York Knicks | Oklahoma City Thunder | Orlando Magic | Philadelphia 76ers | Phoenix Suns | Portland Trail Blazers | Sacramento Kings | San Antonio Spurs | Toronto Raptors | Utah Jazz | Washington Wizards
# ...

# %%
# Write a statement that creates a table that shows the number of movies per studio per year

# %% [markdown]
# ## Join

# %%
nba_rings = Table().with_column('Name', ['Kevin Durant', 'Udonis Haslem', 'Shaun Livingston', 'Andre Iguodala', 'Draymond Green', 'Klay Thompson', 'Stephen Curry', 'Dwayne Wade', 'Lebron James', 'Tony Parker'])
nba_rings = nba_player.with_column('Number of Championships', [2, 3, 3, 3, 3, 3, 3, 3, 3, 4])

# %%
nba.join('PLAYER', nba_rings, 'Name')
# Out:
# PLAYER           | POSITION | TEAM                  | '15-'16 SALARY | Number of Championships
# Andre Iguodala   | SF       | Golden State Warriors | 11.7105        | 3
# Draymond Green   | PF       | Golden State Warriors | 14.2609        | 3
# Kevin Durant     | SF       | Oklahoma City Thunder | 20.1586        | 2
# Klay Thompson    | SG       | Golden State Warriors | 15.501         | 3
# Shaun Livingston | PG       | Golden State Warriors | 5.54373        | 3
# Stephen Curry    | PG       | Golden State Warriors | 11.3708        | 3
# Tony Parker      | PG       | San Antonio Spurs     | 13.4375        | 4
# Udonis Haslem    | PF       | Miami Heat            | 2.85494        | 3

# %%
# Write a statement that joins the actors and movies table by the common movie titles

# %% [markdown]
# ## Booleans and Conditionals

# %% [markdown]
# <statement a> and <statement b>
#     * both have to be True for the entire statement to be True
# <statement a> and <statement b>
#     * only ONE has to be True for the entire statement to be True

# %% [markdown]
# not <statement c>
#     * results in the opposite of statement c

# %% [markdown]
# if <condition>:
#     <some code>
# [elif <condition>:
#     <some code>]
# [else:
#     <some code>]

# %%
# not
bool1 = True
bool2 = False

print(not bool2 and bool1)
print(not(bool2 and bool1))
