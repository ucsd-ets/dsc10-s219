# %% [markdown]
# ## Tables

# %%
from datascience import *
import numpy as np

# %%
data = Table.read_table('actors.csv')
data
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie                     | Gross
# Harrison Ford      | 4871.7      | 41               | 118.8             | Star Wars: The Force Awakens | 936.7
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers                 | 623.4
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight              | 534.9
# Tom Hanks          | 4340.8      | 44               | 98.7              | Toy Story 3                  | 415
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers                 | 623.4
# Eddie Murphy       | 3810.4      | 38               | 100.3             | Shrek 2                      | 441.2
# Tom Cruise         | 3587.2      | 36               | 99.6              | War of the Worlds            | 234.3
# Johnny Depp        | 3368.6      | 45               | 74.9              | Dead Man's Chest             | 423.3
# Michael Caine      | 3351.5      | 58               | 57.8              | The Dark Knight              | 534.9
# Scarlett Johansson | 3341.2      | 37               | 90.3              | The Avengers                 | 623.4
# ... (40 rows omitted)

# %%
# get column as array of values
data.column('Gross')
# Out:
# array([936.7, 623.4, 534.9, 415. , 623.4, 441.2, 234.3, 423.3, 534.9,
#        623.4, 534.9, 250.9, 293.5, 623.4, 936.7, 377.8, 306.2, 424.7,
#        228.4, 279.3, 441.2, 474.5, 936.7, 459. , 279.3, 381. , 423.3,
#        424.7, 377.8, 183.4, 424.7, 381. , 381. , 250.7, 202.4, 169.7,
#        381. , 257.8, 250.9, 459. , 350.1, 245.4, 260. , 279.3, 658.7,
#        623.4, 424.7, 336. , 623.4, 448.1])

# %%
# .item() can be used on arrays
data.column('Gross').item(5)
# Out:
# 441.2

# %%
# get column(s) as new table
data.select('Gross')
# Out:
# Gross
# 936.7
# 623.4
# 534.9
# 415
# 623.4
# 441.2
# 234.3
# 423.3
# 534.9
# 623.4
# ... (40 rows omitted)

# %%
data.select('Gross', 'Total Gross') # notice order of columns
# Out:
# Gross | Total Gross
# 936.7 | 4871.7
# 623.4 | 4772.8
# 534.9 | 4468.3
# 415   | 4340.8
# 623.4 | 3947.3
# 441.2 | 3810.4
# 234.3 | 3587.2
# 423.3 | 3368.6
# 534.9 | 3351.5
# 623.4 | 3341.2
# ... (40 rows omitted)

# %%
data.column('Gross') - data.column('Average per Movie')
# Out:
# array([817.9, 554.2, 461.6, 316.3, 548.9, 340.9, 134.7, 348.4, 477.1,
#        533.1, 448.2, 184. , 240.3, 549.6, 484.9, 276.2, 175. , 362.2,
#        148.7, 240.3, 352. , 427.8, 811. , 374.1, 202.9, 302.6, 257.7,
#        368.4, 305.9, 118.3, 346.8, 305.6, 223.2, 192.4, 135.4,  86.5,
#        226. , 168. , 184.2, 359.7, 247.8, 174.6, 165.7, 220.6, 558. ,
#        504.3, 363.1, 265.6, 516.5, 351.4])

# %%
# Adding a column
# example: Average gross
data.with_column('Difference from Avg Gross', data.column('Gross') - data.column('Average per Movie'))
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie                     | Gross | Difference from Avg Gross
# Harrison Ford      | 4871.7      | 41               | 118.8             | Star Wars: The Force Awakens | 936.7 | 817.9
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers                 | 623.4 | 554.2
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight              | 534.9 | 461.6
# Tom Hanks          | 4340.8      | 44               | 98.7              | Toy Story 3                  | 415   | 316.3
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers                 | 623.4 | 548.9
# Eddie Murphy       | 3810.4      | 38               | 100.3             | Shrek 2                      | 441.2 | 340.9
# Tom Cruise         | 3587.2      | 36               | 99.6              | War of the Worlds            | 234.3 | 134.7
# Johnny Depp        | 3368.6      | 45               | 74.9              | Dead Man's Chest             | 423.3 | 348.4
# Michael Caine      | 3351.5      | 58               | 57.8              | The Dark Knight              | 534.9 | 477.1
# Scarlett Johansson | 3341.2      | 37               | 90.3              | The Avengers                 | 623.4 | 533.1
# ... (40 rows omitted)

# %%
# Did any of these function calls change the original actor_data table?
# No

# %%
# What would we need to do if we wanted to change the data table or store any changes we made?
data = data.with_column('Difference from Avg Gross', data.column('Gross') - data.column('Average per Movie'))

# %%
data
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie                     | Gross | Difference from Avg Gross
# Harrison Ford      | 4871.7      | 41               | 118.8             | Star Wars: The Force Awakens | 936.7 | 817.9
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers                 | 623.4 | 554.2
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight              | 534.9 | 461.6
# Tom Hanks          | 4340.8      | 44               | 98.7              | Toy Story 3                  | 415   | 316.3
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers                 | 623.4 | 548.9
# Eddie Murphy       | 3810.4      | 38               | 100.3             | Shrek 2                      | 441.2 | 340.9
# Tom Cruise         | 3587.2      | 36               | 99.6              | War of the Worlds            | 234.3 | 134.7
# Johnny Depp        | 3368.6      | 45               | 74.9              | Dead Man's Chest             | 423.3 | 348.4
# Michael Caine      | 3351.5      | 58               | 57.8              | The Dark Knight              | 534.9 | 477.1
# Scarlett Johansson | 3341.2      | 37               | 90.3              | The Avengers                 | 623.4 | 533.1
# ... (40 rows omitted)

# %%
# What if we wanted to remove the added column?
data = data.drop('Difference from Avg Gross')

# %%
data
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie                     | Gross
# Harrison Ford      | 4871.7      | 41               | 118.8             | Star Wars: The Force Awakens | 936.7
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers                 | 623.4
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight              | 534.9
# Tom Hanks          | 4340.8      | 44               | 98.7              | Toy Story 3                  | 415
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers                 | 623.4
# Eddie Murphy       | 3810.4      | 38               | 100.3             | Shrek 2                      | 441.2
# Tom Cruise         | 3587.2      | 36               | 99.6              | War of the Worlds            | 234.3
# Johnny Depp        | 3368.6      | 45               | 74.9              | Dead Man's Chest             | 423.3
# Michael Caine      | 3351.5      | 58               | 57.8              | The Dark Knight              | 534.9
# Scarlett Johansson | 3341.2      | 37               | 90.3              | The Avengers                 | 623.4
# ... (40 rows omitted)

# %%
# Now try adding a column called '#1 Movie Gross %'
# that calculates what percent of the 'Total Gross'
# is from the 'Gross'
data = data.with_column('#1 Movie Gross %', data.column('Gross') / data.column('Total Gross') * 100) 
data = data.drop('#1 Movie Gross %')
data
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie                     | Gross
# Harrison Ford      | 4871.7      | 41               | 118.8             | Star Wars: The Force Awakens | 936.7
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers                 | 623.4
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight              | 534.9
# Tom Hanks          | 4340.8      | 44               | 98.7              | Toy Story 3                  | 415
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers                 | 623.4
# Eddie Murphy       | 3810.4      | 38               | 100.3             | Shrek 2                      | 441.2
# Tom Cruise         | 3587.2      | 36               | 99.6              | War of the Worlds            | 234.3
# Johnny Depp        | 3368.6      | 45               | 74.9              | Dead Man's Chest             | 423.3
# Michael Caine      | 3351.5      | 58               | 57.8              | The Dark Knight              | 534.9
# Scarlett Johansson | 3341.2      | 37               | 90.3              | The Avengers                 | 623.4
# ... (40 rows omitted)

# %%
# Sorting
data.sort(0)
# Out:
# Actor           | Total Gross | Number of Movies | Average per Movie | #1 Movie                     | Gross
# Adam Sandler    | 2661        | 32               | 83.2              | Hotel Transylvania 2         | 169.7
# Andy Serkis     | 2890.6      | 23               | 125.7             | Star Wars: The Force Awakens | 936.7
# Anne Hathaway   | 2416.5      | 25               | 96.7              | The Dark Knight Rises        | 448.1
# Anthony Daniels | 3162.9      | 7                | 451.8             | Star Wars: The Force Awakens | 936.7
# Ben Stiller     | 2827        | 37               | 76.4              | Meet the Fockers             | 279.3
# Brad Pitt       | 2680.9      | 40               | 67                | World War Z                  | 202.4
# Bradley Cooper  | 2557.7      | 25               | 102.3             | American Sniper              | 350.1
# Bruce Willis    | 3189.4      | 60               | 53.2              | Sixth Sense                  | 293.5
# Cameron Diaz    | 3031.7      | 34               | 89.2              | Shrek 2                      | 441.2
# Cate Blanchett  | 2802.6      | 39               | 71.9              | Return of the King           | 377.8
# ... (40 rows omitted)

# %%
# How would we get the name of the movie with the highest 'Gross' in the table?
data.sort(5, descending=True).column('#1 Movie')[0]
#data.sort(5, descending=True).column('#1 Movie').item(0) #same
# Out:
# 'Star Wars: The Force Awakens'

# %%
# How would we get the name of the actor with the highest 'Total Gross' in the table?
data.sort("Total Gross", descending=True).column('Actor').item(0)
# Out:
# 'Harrison Ford'

# %%
# Rows
# take() - returns table with specified row indexes
data.take(19)
# Out:
# Actor         | Total Gross | Number of Movies | Average per Movie | #1 Movie         | Gross
# Robert DeNiro | 3081.3      | 79               | 39                | Meet the Fockers | 279.3

# %%
# multiple rows
data.take([0, 1, 2, 3, 4])
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie                     | Gross
# Harrison Ford      | 4871.7      | 41               | 118.8             | Star Wars: The Force Awakens | 936.7
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers                 | 623.4
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight              | 534.9
# Tom Hanks          | 4340.8      | 44               | 98.7              | Toy Story 3                  | 415
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers                 | 623.4

# %%
type(data)
# Out:
# NoneType

# %%
# can add rows using with_row function
# provide values as ___ (what data type?)
data = data.with_row(['New Actor', '500', 20, 25, 'New Movie', 5])
data.column('Total Gross')
# Out:
# array(['4871.7', '4772.8', '4468.3', '4340.8', '3947.3', '3810.4',
#        '3587.2', '3368.6', '3351.5', '3341.2', '3294.0', '3279.3',
#        '3189.4', '3175.0', '3162.9', '3150.4', '3149.1', '3123.9',
#        '3107.3', '3081.3', '3031.7', '2942.7', '2890.6', '2885.4',
#        '2827.0', '2822.0', '2815.8', '2815.8', '2802.6', '2735.3',
#        '2726.3', '2715.3', '2681.9', '2681.3', '2680.9', '2661.0',
#        '2634.4', '2605.1', '2602.3', '2580.6', '2557.7', '2549.8',
#        '2545.2', '2522.1', '2518.3', '2500.3', '2463.7', '2462.6',
#        '2457.8', '2416.5', '500', '500', '500', '500', '500', '500',
#        '500'], dtype='<U32')

# %%
# Predicates
# rows where the values in 'Number of Movies' are above 50
data.where('Number of Movies', are.above(50))
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie           | Gross
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers       | 623.4
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight    | 534.9
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers       | 623.4
# Michael Caine      | 3351.5      | 58               | 57.8              | The Dark Knight    | 534.9
# Bruce Willis       | 3189.4      | 60               | 53.2              | Sixth Sense        | 293.5
# Robert DeNiro      | 3081.3      | 79               | 39                | Meet the Fockers   | 279.3
# Liam Neeson        | 2942.7      | 63               | 46.7              | The Phantom Menace | 474.5

# %%
# How would I get the rows where '#1 Movie' contains 'Avengers'
avenge = data.where('#1 Movie', are.containing('Avengers'))

# %%
def check_above_50(x):
    return x > 50

# %%
# write function that takes a string as an argument
# and checks whether the string starts with 'A'
# (return True if it does, false if it doesn't)
def starts_with_A(x):
    return x.item(0) == 'A'

# %%
data.where('Actor', starts_with_A)
# Out:
# Actor | Total Gross | Number of Movies | Average per Movie | #1 Movie | Gross

# %%
data.where('Number of Movies', check_above_50)
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie           | Gross
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers       | 623.4
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight    | 534.9
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers       | 623.4
# Michael Caine      | 3351.5      | 58               | 57.8              | The Dark Knight    | 534.9
# Bruce Willis       | 3189.4      | 60               | 53.2              | Sixth Sense        | 293.5
# Robert DeNiro      | 3081.3      | 79               | 39                | Meet the Fockers   | 279.3
# Liam Neeson        | 2942.7      | 63               | 46.7              | The Phantom Menace | 474.5

# %%
data.where('#1 Movie', are.containing('Avengers'))
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie                | Gross
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers            | 623.4
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers            | 623.4
# Scarlett Johansson | 3341.2      | 37               | 90.3              | The Avengers            | 623.4
# Stellan Skarsgard  | 3175.0      | 43               | 73.8              | The Avengers            | 623.4
# Don Cheadle        | 2885.4      | 34               | 84.9              | Avengers: Age of Ultron | 459
# Idris Elba         | 2580.6      | 26               | 99.3              | Avengers: Age of Ultron | 459
# Jeremy Renner      | 2500.3      | 21               | 119.1             | The Avengers            | 623.4
# Chris Evans        | 2457.8      | 23               | 106.9             | The Avengers            | 623.4

# %%
# Of the Actors whose '#1 Movie' contains 'Avengers',
# who has made the most Number of Movies?
data.where('#1 Movie', are.containing('Avengers')).sort('Number of Movies',descending=True).column('Actor').item(0)
# Out:
# 'Samuel L. Jackson'

# %% [markdown]
# ## Visualizing Data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
# Scatters are better for showing relationship between two numerical values
data.scatter('Number of Movies', 'Total Gross')

# %%
nba = Table.read_table('nba_salaries.csv')
nba
# Out:
# PLAYER           | POSITION | TEAM          | '15-'16 SALARY
# Paul Millsap     | PF       | Atlanta Hawks | 18.6717
# Al Horford       | C        | Atlanta Hawks | 12
# Tiago Splitter   | C        | Atlanta Hawks | 9.75625
# Jeff Teague      | PG       | Atlanta Hawks | 8
# Kyle Korver      | SG       | Atlanta Hawks | 5.74648
# Thabo Sefolosha  | SF       | Atlanta Hawks | 4
# Mike Scott       | PF       | Atlanta Hawks | 3.33333
# Kent Bazemore    | SF       | Atlanta Hawks | 2
# Dennis Schroder  | PG       | Atlanta Hawks | 1.7634
# Tim Hardaway Jr. | SG       | Atlanta Hawks | 1.30452
# ... (407 rows omitted)

# %%
nba.scatter('POSITION', "'15-'16 SALARY")
# What type of graph would be for showing a relationship between these columns?

# %%
# A bar graph can show categorical distributions
# What are the categories in this case?
# How can we create a bar graph showing the average salary of each position?

# %%
# First, let's create a column called "Position Average Salary"
nba_avg_sal = nba.group('POSITION',np.average)
#nba.with_column('Position Average Salary', )
# Now, we can graph these using barh
nba_avg_sal.barh('POSITION', "'15-'16 SALARY average")

# %%
# Histograms show distribution of bins
# If we want to choose bins for "'15-'16 SALARY" we need to know min and max
print(min(nba.column("'15-'16 SALARY")))
print(max(nba.column("'15-'16 SALARY")))
# Out:
# 0.030888
# 25.0

# %%
salary_bins = np.arange(0, 26, 5)
print(salary_bins)
nba.bin("'15-'16 SALARY", bins=salary_bins)
# Out:
# [ 0  5 10 15 20 25]
# bin  | '15-'16 SALARY count
# 0    | 270
# 5    | 77
# 10   | 39
# 15   | 21
# 20   | 10
# 25   | 0

# %%
# Create histogram
nba.hist("'15-'16 SALARY", bins=salary_bins, unit='millions of $', normed=False)

# %% [markdown]
# ## Functions

# %%
# Here's a very simple function that takes two values and returns their sum
def my_sum_func(a, b):
    return a + b

# %%
my_sum_func("hello, ", 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-66d618ed63b1> in <module>()
# ----> 1 my_sum_func("hello, ", 4)
#
# <ipython-input-95-c2ea67ec407f> in my_sum_func(a, b)
#       1 # Here's a very simple function that takes two values and returns their sum
#       2 def my_sum_func(a, b):
# ----> 3     return a + b
#
# TypeError: must be str, not int

# %%
test = "hello, my name is larry"
test2 = "abbbba banana apple"
test2.split()
# Out:
# ['abbbba', 'banana', 'apple']

# %%
# let's write a function that takes a string, s, and returns the first word in the string
def get_first_word(s):
    return s.split()[0]

def get_last_word(s):
    return s.split()[-1]

# %%
# now let's apply this function to the nba table and add
# a new column that contains the first name of each player
nba.with_column('First Name', nba.apply(get_first_word, 'PLAYER'))
# Out:
# PLAYER           | POSITION | TEAM          | '15-'16 SALARY | First Name
# Paul Millsap     | PF       | Atlanta Hawks | 18.6717        | Paul
# Al Horford       | C        | Atlanta Hawks | 12             | Al
# Tiago Splitter   | C        | Atlanta Hawks | 9.75625        | Tiago
# Jeff Teague      | PG       | Atlanta Hawks | 8              | Jeff
# Kyle Korver      | SG       | Atlanta Hawks | 5.74648        | Kyle
# Thabo Sefolosha  | SF       | Atlanta Hawks | 4              | Thabo
# Mike Scott       | PF       | Atlanta Hawks | 3.33333        | Mike
# Kent Bazemore    | SF       | Atlanta Hawks | 2              | Kent
# Dennis Schroder  | PG       | Atlanta Hawks | 1.7634         | Dennis
# Tim Hardaway Jr. | SG       | Atlanta Hawks | 1.30452        | Tim
# ... (407 rows omitted)

# %%
# function that returns all but last word
def all_but_last(s):
    return ' '.join(s.split()[:-1])

# %%
nba.with_column('Location', nba.apply(all_but_last, 'TEAM')).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PLAYER</th> <th>POSITION</th> <th>TEAM</th> <th>'15-'16 SALARY</th> <th>Location</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Paul Millsap            </td> <td>PF      </td> <td>Atlanta Hawks         </td> <td>18.6717       </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Al Horford              </td> <td>C       </td> <td>Atlanta Hawks         </td> <td>12            </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Tiago Splitter          </td> <td>C       </td> <td>Atlanta Hawks         </td> <td>9.75625       </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Jeff Teague             </td> <td>PG      </td> <td>Atlanta Hawks         </td> <td>8             </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Kyle Korver             </td> <td>SG      </td> <td>Atlanta Hawks         </td> <td>5.74648       </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Thabo Sefolosha         </td> <td>SF      </td> <td>Atlanta Hawks         </td> <td>4             </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Mike Scott              </td> <td>PF      </td> <td>Atlanta Hawks         </td> <td>3.33333       </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Kent Bazemore           </td> <td>SF      </td> <td>Atlanta Hawks         </td> <td>2             </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Dennis Schroder         </td> <td>PG      </td> <td>Atlanta Hawks         </td> <td>1.7634        </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Tim Hardaway Jr.        </td> <td>SG      </td> <td>Atlanta Hawks         </td> <td>1.30452       </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Walter Tavares          </td> <td>C       </td> <td>Atlanta Hawks         </td> <td>1             </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Jason Richardson        </td> <td>SG      </td> <td>Atlanta Hawks         </td> <td>0.947276      </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Lamar Patterson         </td> <td>SG      </td> <td>Atlanta Hawks         </td> <td>0.525093      </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Terran Petteway         </td> <td>SG      </td> <td>Atlanta Hawks         </td> <td>0.525093      </td> <td>Atlanta       </td>
#         </tr>
#         <tr>
#             <td>Avery Bradley           </td> <td>PG      </td> <td>Boston Celtics        </td> <td>7.73034       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Isaiah Thomas           </td> <td>PG      </td> <td>Boston Celtics        </td> <td>6.91287       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Jae Crowder             </td> <td>SF      </td> <td>Boston Celtics        </td> <td>6.79612       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Jonas Jerebko           </td> <td>PF      </td> <td>Boston Celtics        </td> <td>5             </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Marcus Smart            </td> <td>PG      </td> <td>Boston Celtics        </td> <td>3.43104       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Evan Turner             </td> <td>SG      </td> <td>Boston Celtics        </td> <td>3.42551       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Tyler Zeller            </td> <td>C       </td> <td>Boston Celtics        </td> <td>2.61698       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Jared Sullinger         </td> <td>C       </td> <td>Boston Celtics        </td> <td>2.56926       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Kelly Olynyk            </td> <td>C       </td> <td>Boston Celtics        </td> <td>2.16516       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Perry Jones             </td> <td>SF      </td> <td>Boston Celtics        </td> <td>2.03821       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Terry Rozier            </td> <td>PG      </td> <td>Boston Celtics        </td> <td>1.82436       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>James Young             </td> <td>SG      </td> <td>Boston Celtics        </td> <td>1.74984       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Zoran Dragic            </td> <td>SG      </td> <td>Boston Celtics        </td> <td>1.70623       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Jordan Mickey           </td> <td>PF      </td> <td>Boston Celtics        </td> <td>1.17096       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>R.J. Hunter             </td> <td>SG      </td> <td>Boston Celtics        </td> <td>1.14864       </td> <td>Boston        </td>
#         </tr>
#         <tr>
#             <td>Joe Johnson             </td> <td>SF      </td> <td>Brooklyn Nets         </td> <td>24.8949       </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Thaddeus Young          </td> <td>PF      </td> <td>Brooklyn Nets         </td> <td>11.236        </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Jarrett Jack            </td> <td>PG      </td> <td>Brooklyn Nets         </td> <td>6.3           </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Bojan Bogdanovic        </td> <td>SG      </td> <td>Brooklyn Nets         </td> <td>3.42551       </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Sergey Karasev          </td> <td>SG      </td> <td>Brooklyn Nets         </td> <td>1.59984       </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Wayne Ellington         </td> <td>SG      </td> <td>Brooklyn Nets         </td> <td>1.5           </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Shane Larkin            </td> <td>PG      </td> <td>Brooklyn Nets         </td> <td>1.5           </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Andrea Bargnani         </td> <td>C       </td> <td>Brooklyn Nets         </td> <td>1.3629        </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Rondae Hollis-Jefferson </td> <td>SG      </td> <td>Brooklyn Nets         </td> <td>1.33548       </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Earl Clark              </td> <td>SF      </td> <td>Brooklyn Nets         </td> <td>1.18578       </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Chris McCullough        </td> <td>PF      </td> <td>Brooklyn Nets         </td> <td>1.14024       </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Thomas Robinson         </td> <td>PF      </td> <td>Brooklyn Nets         </td> <td>0.981348      </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Markel Brown            </td> <td>SG      </td> <td>Brooklyn Nets         </td> <td>0.845059      </td> <td>Brooklyn      </td>
#         </tr>
#         <tr>
#             <td>Al Jefferson            </td> <td>C       </td> <td>Charlotte Hornets     </td> <td>13.5          </td> <td>Charlotte     </td>
#         </tr>
#         <tr>
#             <td>Nicolas Batum           </td> <td>SG      </td> <td>Charlotte Hornets     </td> <td>13.1253       </td> <td>Charlotte     </td>
#         </tr>
#         <tr>
#             <td>Kemba Walker            </td> <td>PG      </td> <td>Charlotte Hornets     </td> <td>12            </td> <td>Charlotte     </td>
#         </tr>
#         <tr>
#             <td>Marvin Williams         </td> <td>PF      </td> <td>Charlotte Hornets

# %%
def test_func(a, b):
    return a + " " + b
nba.apply(test_func, 'PLAYER', 'POSITION')
# specify more values/columns for functions that take multiple arguments
# Out:
# array(['Paul Millsap PF', 'Al Horford C', 'Tiago Splitter C',
#        'Jeff Teague PG', 'Kyle Korver SG', 'Thabo Sefolosha SF',
#        'Mike Scott PF', 'Kent Bazemore SF', 'Dennis Schroder PG',
#        'Tim Hardaway Jr. SG', 'Walter Tavares C', 'Jason Richardson SG',
#        'Lamar Patterson SG', 'Terran Petteway SG', 'Avery Bradley PG',
#        'Isaiah Thomas PG', 'Jae Crowder SF', 'Jonas Jerebko PF',
#        'Marcus Smart PG', 'Evan Turner SG', 'Tyler Zeller C',
#        'Jared Sullinger C', 'Kelly Olynyk C', 'Perry Jones SF',
#        'Terry Rozier PG', 'James Young SG', 'Zoran Dragic SG',
#        'Jordan Mickey PF', 'R.J. Hunter SG', 'Joe Johnson SF',
#        'Thaddeus Young PF', 'Jarrett Jack PG', 'Bojan Bogdanovic SG',
#        'Sergey Karasev SG', 'Wayne Ellington SG', 'Shane Larkin PG',
#        'Andrea Bargnani C', 'Rondae Hollis-Jefferson SG', 'Earl Clark SF',
#        'Chris McCullough PF', 'Thomas Robinson PF', 'Markel Brown SG',
#        'Al Jefferson C', 'Nicolas Batum SG', 'Kemba Walker PG',
#        'Marvin Williams PF', 'Michael Kidd-Gilchrist SF',
#        'Spencer Hawes PF', 'Courtney Lee SG', 'Cody Zeller C',
#        'Jeremy Lamb SG', 'Brian Roberts PG', 'Frank Kaminsky III C',
#        'Jeremy Lin PG', 'P.J. Hairston SF', 'Damien Wilkins SG',
#        'Jorge Gutierrez PG', 'Tyler Hansbrough PF', 'Troy Daniels SG',
#        'Aaron Harrison SG', 'Derrick Rose PG', 'Jimmy Butler SG',
#        'Joakim Noah C', 'Pau Gasol C', 'Nikola Mirotic PF',
#        'Mike Dunleavy SG', 'Kirk Hinrich SG', 'Doug McDermott SF',
#        'Aaron Brooks PG', 'Tony Snell SF', 'Bobby Portis PF',
#        "E'Twaun Moore SG", 'LeBron James SF', 'Kevin Love PF',
#        'Kyrie Irving PG', 'Tristan Thompson C', 'Brendan Haywood C',
#        'Iman Shumpert SG', 'Timofey Mozgov C', 'Mo Williams PG',
#        'Sasha Kaun C', 'Matthew Dellavedova PG', 'David Lee PF',
#        'Chandler Parsons SF', 'Dirk Nowitzki PF', 'Deron Williams PG',
#        'Zaza Pachulia C', 'J.J. Barea PG', 'Devin Harris PG',
#        'Raymond Felton PG', 'Justin Anderson SG', 'JaVale McGee C',
#        'John Jenkins SG', 'Danilo Gallinari SF', 'Kenneth Faried PF',
#        'Wilson Chandler SF', 'JJ Hickson C', 'Jameer Nelson PG',
#        'Will Barton SF', 'Emmanuel Mudiay PG', 'Darrell Arthur PF',
#        'Jusuf Nurkic C', 'Joffrey Lauvergne C', 'Gary Harris SG',
#        'Nikola Jokic C', 'Kostas Papanikolaou SF', 'Sean Kilpatrick SG',
#        'Reggie Jackson PG', 'Aron Baynes C', 'Jodie Meeks SG',
#        'Andre Drummond C', 'Kentavious Caldwell-Pope SG',
#        'Stanley Johnson SF', 'Joel Anthony C', 'Danny Granger SF',
#        'Reggie Bullock SF', 'Darrun Hilliard SF', 'Klay Thompson SG',
#        'Draymond Green PF', 'Andrew Bogut C', 'Andre Iguodala SF',
#        'Stephen Curry PG', 'Jason Thompson PF', 'Shaun Livingston PG',
#        'Harrison Barnes SF', 'Marreese Speights C', 'Leandro Barbosa SG',
#        'Festus Ezeli C', 'Brandon Rush SF', 'Kevon Looney SF',
#        'Anderson Varejao PF', 'Dwight Howard C', 'James Harden SG',
#        'Ty Lawson PG', 'Corey Brewer SG', 'Trevor Ariza SF',
#        'Patrick Beverley PG', 'K.J. McDaniels SG', 'Terrence Jones PF',
#        'Donatas Motiejunas PF', 'Sam Dekker SF', 'Clint Capela PF',
#        'Montrezl Harrell PF', 'Paul George SF', 'Monta Ellis SG',
#        'Rodney Stuckey PG', 'Chase Budinger SF', 'C.J. Miles SF',
#        'Lavoy Allen PF', 'Jordan Hill C', 'Ian Mahinmi C',
#        'Myles Turner PF', 'Solomon Hill SF', 'Glenn Robinson III SG',
#        'Rakeem Christmas PF', 'Joe Young PG', 'Chris Paul PG',
#        'Blake Griffin PF', 'J.J. Redick SG', 'Jamal Crawford SG',
#        'Paul Pierce SF', 'Austin Rivers PG', 'C.J. Wilcox SG',
#        'Cole Aldrich C', 'Wesley Johnson SF', 'Jordan Hamilton SG',
#        'Lester Hudson SG', 'Pablo Prigioni PG', 'Jeff Ayres PF',
#        'Kobe Bryant SF', 'Roy Hibbert C', 'Louis Williams SG',
#        'Nick Young SF', "D'Angelo Russell PG", 'Julius Randle PF',
#        'Brandon Bass PF', 'Ryan Kelly PF', 'Larry Nance Jr. PF',
#        'Robert Sacre C', 'Anthony Brown SF', 'Marc Gasol C',
#        'Zach Randolph PF', 'Mike Conley PG', 'Jeff Green SF',
#        'Lance Stephenson SF', 'Brandan Wright PF', 'Tony Allen SG',
#        'Chris Andersen PF', 'Mario Chalmers PG', 'Vince Carter SG',
#        'Matt Barnes SF', 'Beno Udrih PG', 'Jordan Adams SG',
#        'Jarell Martin PF', 'JaMychal Green PF', 'Russ Smith PG',
#        'James Ennis SF', 'Jarnell Stokes PF', 'Jarrid Famous PF',
#        'Ryan Hollins C', 'Elliot Williams SG', 'Chris Bosh PF',
#        'Dwyane Wade SG', 'Goran Dragic PG', 'Luol Deng SF',
#        'Josh McRoberts PF', 'Udonis Haslem PF', 'Justise Winslow SF',
#        'Henry Walker SF', 'Tyler Johnson SG', 'Greg Whittington SF',
#        'Josh Richardson SG', 'Corey Hawkins PG', 'Khris Middleton SG',
#        'O.J. Mayo SG', 'Greivis Vasquez PG', 'Jabari Parker PF',
#        'Jerryd Bayless PG', 'John Henson PF',
#        'Michael Carter-Williams PG', 'Miles Plumlee C',
#        'Giannis Antetokounmpo SF', 'Rashad Vaughn SG', 'Tyler Ennis PG',
#        'Chris Copeland SF', 'Damien Inglis SF', 'Ricky Rubio PG',
#        'Nikola Pekovic C', 'Kevin Garnett PF', 'Kevin Martin SG',
#        'Andrew Wiggins SG', 'Karl-Anthony Towns C', 'Nemanja Bjelica PF',
#        'Zach LaVine PG', 'Shabazz Muhammad SF', 'Adreian Payne PF',
#        'Gorgui Dieng C', 'Tyus Jones PG', 'Damjan Rudez SF',
#        'Eric Gordon SG', 'Tyreke Evans SG', 'Jrue Holiday PG',
#        'Omer Asik C', 'Ryan Anderson PF', 'Anthony Davis PF',
#        'Alexis Ajinca C', 'Quincy Pondexter SF', 'Norris Cole PG',
#        'Dante Cunningham PF', 'Alonzo Gee SF', 'Toney Douglas PG',
#        'Luke Babbitt SF', 'Kendrick Perkins C', 'Bo McCalebb PG',
#        'Bryce Dejean-Jones SG', 'Carmelo Anthony SF', 'Robin Lopez C',
#        'Arron Afflalo SG', 'Jose Calderon PG', 'Kristaps Porzingis PF',
#        'Derrick Williams PF', "Kyle O'Quinn PF", 'Lance Thomas SF',
#        'Lou Amundson PF', 'Jerian Grant PG', 'Jimmer Fredette PG',
#        'Langston Galloway SG', 'Thanasis Antetokounmpo SF',
#        'Kevin Durant SF', 'Russell Westbrook PG', 'Enes Kanter C',
#        'Serge Ibaka PF', 'Dion Waiters SG', 'Kyle Singler SF',
#        'Nick Collison PF', 'Anthony Morrow SG', 'Randy Foye SG',
#        'D.J. Augustin PG', 'Steven Adams C', 'Cameron Payne PG',
#        'Mitch McGary PF', 'Andre Roberson SG', 'Josh Huestis SF',
#        'Steve Novak SF', 'Tobias Harris SF', 'Nikola Vucevic C',
#        'Brandon Jennings PG', 'Channing Frye PF', 'Ersan Ilyasova PF',
#        'Victor Oladipo SG', 'Jason Smith PF', 'Aaron Gordon PF',
#        'Mario Hezonja SG', 'Elfrid Payton PG', 'Andrew Nicholson PF',
#        'Evan Fournier SG', 'Shabazz Napier PG', 'Keith Appling PG',
#        'Gerald Wallace SF', 'Carl Landry PF', 'Joel Embiid C',
#        'Jahlil Okafor C', 'Nerlens Noel PF', 'Nik Stauskas SG',
#        'Furkan Aldemir PF', 'Tony Wroten SG', 'Kendall Marshall PG',
#        'Richaun Holmes PF', 'Robert Covington SF', 'Jerami Grant SF',
#        'JaKarr Sampson SG', 'Eric Bledsoe PG', 'Tyson Chandler C',
#        'Mirza Teletovic PF', 'P.J. Tucker SF', 'Alex Len C',
#        'Devin Booker SG', 'T.J. Warren SF', 'Archie Goodwin SG',
#        'Jon Leuer PF', 'Jerel McNeal SG', 'Terrico White SG',
#        'Bryce Cotton PG', 'Lorenzo Brown PG', 'Orlando Johnson SG',
#        'Phil Pressey PG', 'Jordan McRae SG', 'Cory Jefferson PF',
#        'Al-Farouq Aminu SF', 'Ed Davis C', 'Gerald Henderson SG',
#        'Chris Kaman C', 'Damian Lillard PG', 'Meyers Leonard PF',
#        'Maurice Harkless SF', 'Noah Vonleh PF', 'C.J. McCollum SG',
#        'Mason Plumlee C', 'Allen Crabbe SG', 'Pat Connaughton SG',
#        'Luis Montero SG', 'Cliff Alexander PF', 'DeMarcus Cousins C',
#        'Rudy Gay SF', 'Rajon Rondo PG', 'Kosta Koufos C',
#        'Marco Belinelli SG', 'Darren Collison PG',
#        'Willie Cauley-Stein C', 'Ben McLemore SG', 'Omri Casspi SF',
#        'Caron Butler SF', 'James Anderson SG', 'LaMarcus Aldridge PF',
#        'Kawhi Leonard SF', 'Tony Parker PG', 'Danny Green SG',
#        'Boris Diaw C', 'Tim Duncan C', 'Patty Mills PG',
#        'Manu Ginobili SG', 'David West PF', 'Boban Marjanovic C',
#        'Reggie Williams SF', 'Kyle Anderson SF', 'Ray McCallum PG',
#        'DeMarre Carroll SF', 'Kyle Lowry PG', 'DeMar DeRozan SG',
#        'Cory Joseph PG', 'Patrick Patterson PF', 'Jonas Valanciunas C',
#        'Terrence Ross SF', 'Luis Scola PF', 'Bismack Biyombo C',
#        'Luke Ridnour PG', 'James Johnson PF', 'Lucas Nogueira C',
#        'Bruno Caboclo SF', 'Delon Wright PG', 'Norman Powell SG',
#        'Shannon Scott PG', 'Ronald Roberts Jr. PF', 'Gordon Hayward SF',
#        'Alec Burks SG', 'Trevor Booker PF', 'Dante Exum PG',
#        'Tibor Pleiss C', 'Trey Burke PG', 'Shelvin Mack PG',
#        'Trey Lyles PF', 'Joe Ingles SF', 'Rodney Hood SG',
#        'Rudy Gobert C', 'Chris Johnson SF', 'Grant Jerrett PF',
#        'Jeff Withey C', 'Raul Neto PG', 'Treveon Graham SG',
#        'Erick Green PG', 'John Wall PG', 'Nene Hilario C',
#        'Marcin Gortat C', 'Markieff Morris PF', 'Bradley Beal SG',
#        'Martell Webster SF', 'Otto Porter Jr. SF', 'Kris Humphries PF',
#        'Jared Dudley SF', 'Alan Anderson SG', 'Drew Gooden PF',
#        'Ramon Sessions PG', 'Gary Neal PG', 'DeJuan Blair C',
#        'Kelly Oubre Jr. SF', 'Garrett Temple SG', 'Jarell Eddie SG'],
#       dtype='<U27')
